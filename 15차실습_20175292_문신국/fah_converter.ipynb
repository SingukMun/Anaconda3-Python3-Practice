# %%
def convert_c_to_f(celcius_value):
    return celcius_value * 9.0 / 5 +32

# %%
import fah_converter

print ("Enter a celsius value:")
celsius = float(input())
fahrenheit = fah_converter.covert_c_to_f(celsius)
print ("That's", fahrenheit, "degrees Fahrenheit.")
# Out:
# Enter a celsius value:
# 10
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-88aace900f10> in <module>
#       3 print ("Enter a celsius value:")
#       4 celsius = float(input())
# ----> 5 fahrenheit = fah_converter.covert_c_to_f(celsius)
#       6 print ("That's", fahrenheit, "degrees Fahrenheit.")
#
# AttributeError: module 'fah_converter' has no attribute 'covert_c_to_f'

# %%
import fah_converter as fah 
print(fah.covert_c_to_f(41.6))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-b0cc0533156a> in <module>
#       1 import fah_converter as fah
# ----> 2 print(fah.covert_c_to_f(41.6))
#
# AttributeError: module 'fah_converter' has no attribute 'covert_c_to_f'
